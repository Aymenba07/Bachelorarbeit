# %%
import useful_usage as u
import pandas as pd
import numpy as np

# %%
yellow_orginal = u.fetch_data("m6nq-qud6")
yellow_results_df = u.preprocess_data("m6nq-qud6")

# %%
yellow_results_df.nunique()
# Out:
# vendorid                      2
# tpep_pickup_datetime     711581
# tpep_dropoff_datetime    711760
# passenger_count               9
# trip_distance              3423
# ratecodeid                    7
# store_and_fwd_flag            2
# pulocationid                255
# dolocationid                260
# payment_type                  4
# fare_amount                1149
# extra                        19
# mta_tax                       3
# tip_amount                 1922
# tolls_amount                  4
# improvement_surcharge         3
# total_amount               5873
# congestion_surcharge          4
# dtype: int64

# %%
non_num_cols=['vendorid','tpep_pickup_datetime','tpep_dropoff_datetime','pulocationid','dolocationid','ratecodeid', 'store_and_fwd_flag','payment_type']
print(yellow_results_df[non_num_cols].count())
# Out:
# vendorid                 1000000
# tpep_pickup_datetime     1000000
# tpep_dropoff_datetime    1000000
# pulocationid             1000000
# dolocationid             1000000
# ratecodeid               1000000
# store_and_fwd_flag       1000000
# payment_type             1000000
# dtype: int64

# %% [markdown]
# There are no missing values for the non numeric columns.

# %%
bool_series = yellow_results_df.duplicated(keep='first')
yellow_results_df[~bool_series]
# Out:
#         vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1              1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2              1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3              1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4              2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ...          ...                  ...                   ...              ...
# 999995         1  2021-01-25 17:56:51   2021-01-25 18:08:03                1
# 999996         1  2021-01-25 17:04:55   2021-01-25 17:14:08                1
# 999997         2  2021-01-25 17:27:41   2021-01-25 17:34:51                2
# 999998         2  2021-01-25 17:48:51   2021-01-25 18:01:25                2
# 999999         2  2021-01-25 17:06:14   2021-01-25 17:11:49                1
#
# ...

# %% [markdown]
# There are no duplicates.

# %%
# check outlier
from scipy import stats
z_thr = 3.0
yellow_results_df[(np.abs(stats.zscore(yellow_results_df.passenger_count)) > z_thr)]
# Out:
#         vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 13             2  2021-01-01 00:31:06   2021-01-01 00:38:52                5
# 14             2  2021-01-01 00:42:11   2021-01-01 00:44:24                5
# 49             2  2021-01-01 00:28:07   2021-01-01 00:36:27                5
# 271            2  2021-01-01 00:23:04   2021-01-01 00:26:43                5
# 272            2  2021-01-01 00:33:54   2021-01-01 00:35:44                5
# ...          ...                  ...                   ...              ...
# 999894         2  2021-01-25 17:05:29   2021-01-25 17:16:33                6
# 999895         2  2021-01-25 17:35:53   2021-01-25 17:41:12                6
# 999896         2  2021-01-25 17:43:58   2021-01-25 17:49:37                6
# 999972         2  2021-01-25 17:17:41   2021-01-25 17:23:24                6
# 999973         2  2021-01-25 17:26:11   2021-01-25 17:45:20                6
#
# ...

# %%
yellow_results_df[(np.abs(stats.zscore(yellow_results_df.trip_distance)) > z_thr)]
# Out:
#         vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2              1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 24             1  2021-01-01 00:37:40   2021-01-01 01:04:46                2
# 29             1  2021-01-01 00:24:30   2021-01-01 00:46:32                1
# 36             2  2021-01-01 00:55:13   2021-01-01 01:23:03                1
# 52             1  2021-01-01 00:22:52   2021-01-01 00:43:49                1
# ...          ...                  ...                   ...              ...
# 999603         2  2021-01-25 17:25:47   2021-01-25 18:02:49                1
# 999714         1  2021-01-25 17:45:43   2021-01-25 18:21:34                1
# 999752         2  2021-01-25 17:02:36   2021-01-25 17:33:24                1
# 999805         2  2021-01-25 17:49:28   2021-01-25 18:25:39                1
# 999920         2  2021-01-25 17:44:14   2021-01-25 18:12:01                1
#
# ...

# %%
yellow_results_df[(np.abs(stats.zscore(yellow_results_df.fare_amount)) > z_thr)]
# Out:
#         vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 24             1  2021-01-01 00:37:40   2021-01-01 01:04:46                2
# 52             1  2021-01-01 00:22:52   2021-01-01 00:43:49                1
# 64             2  2021-01-01 00:36:53   2021-01-01 01:01:27                3
# 230            2  2021-01-01 00:17:06   2021-01-01 00:51:26                2
# 276            2  2021-01-01 00:22:05   2021-01-01 00:53:34                1
# ...          ...                  ...                   ...              ...
# 999603         2  2021-01-25 17:25:47   2021-01-25 18:02:49                1
# 999714         1  2021-01-25 17:45:43   2021-01-25 18:21:34                1
# 999752         2  2021-01-25 17:02:36   2021-01-25 17:33:24                1
# 999803         2  2021-01-25 17:05:32   2021-01-25 17:05:39                1
# 999920         2  2021-01-25 17:44:14   2021-01-25 18:12:01                1
#
# ...

# %%
# check missing data
yellow_results_df.isnull().sum()
# Out:
# vendorid                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# ratecodeid               0
# store_and_fwd_flag       0
# pulocationid             0
# dolocationid             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
# check number of unique value
yellow_results_df.nunique()
# Out:
# vendorid                      2
# tpep_pickup_datetime     711581
# tpep_dropoff_datetime    711760
# passenger_count               9
# trip_distance              3423
# ratecodeid                    7
# store_and_fwd_flag            2
# pulocationid                255
# dolocationid                260
# payment_type                  4
# fare_amount                1149
# extra                        19
# mta_tax                       3
# tip_amount                 1922
# tolls_amount                  4
# improvement_surcharge         3
# total_amount               5873
# congestion_surcharge          4
# dtype: int64

# %%
yellow_results_df.skew(axis = 1, skipna = True)
# Out:
# C:\Users\aymen\AppData\Local\Temp\ipykernel_14988\2587885890.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   yellow_results_df.skew(axis = 1, skipna = True)
# 0         3.146703
# 1         2.433012
# 2         1.865267
# 3         1.941701
# 4         2.221129
#             ...
# 999995    2.355408
# 999996    2.191343
# 999997    2.352962
# 999998    3.106753
# 999999    2.161210
# Length: 1000000, dtype: float64
